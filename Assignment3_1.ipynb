# %% [markdown]
# # Assignment 3 - Building a Custom Visualization

# %%
# Use the following data for this assignment:

import pandas as pd
import numpy as np

np.random.seed(12345)

df = pd.DataFrame([np.random.normal(32000,200000,3650), 
                   np.random.normal(43000,100000,3650), 
                   np.random.normal(43500,140000,3650), 
                   np.random.normal(48000,70000,3650)], 
                  index=[1992,1993,1994,1995])
df
# Out:
#                0              1              2              3     \
# 1992   -8941.531897  127788.667612  -71887.743011  -79146.060869
# 1993  -51896.094813  198350.518755 -123518.252821 -129916.759685
# 1994  152336.932066  192947.128056  389950.263156  -93006.152024
# 1995  -69708.439062  -13289.977022  -30178.390991   55052.181256
#
#                4              5              6              7     \
# 1992  425156.114501  310681.166595   50581.575349   88349.230566
# 1993  216119.147314   49845.883728  149135.648505   62807.672113
# 1994  100818.575896    5529.230706  -32989.370488  223942.967178
# 1995  152883.621657   12930.835194   63700.461932   64148.489835
#
#                8              9         ...                3640  \
# 1992  185804.513522  281286.947277      ...       171938.760289
# 1993   23365.577348 -109686.264981      ...       -44566.520071
# 1994  -66721.580898   47826.269111      ...       165085.806360
# 1995  -29316.268556   59645.677367      ...       -13901.388118
#
#                3641           3642           3643           3644  \
# 1992  150650.759924  203663.976475 -377877.158072 -197214.093861
# 1993  101032.122475  117648.199945  160475.622607  -13759.888342
# 1994   74735.174090  107329.726875  199250.734156  -36792.202754
# 1995   50173.686673   53965.990717    4128.990173   72202.595138
#
#               3645           3646           3647           3648          3649
# 1992  24185.008589  -56826.729535  -67319.766489  113377.299342  -4494.878538
# 1993 -37333.493572  103019.841174  179746.127403   13455.493990  34442.898855
# 1994 -71861.846997   26375.113219  -29328.078384   65858.761714 -91542.001049
# 1995  39937.199964  139472.114293   59386.186379   73362.229590  28705.082908
#
# [4 rows x 3650 columns]

# %%
df = df.transpose()
df
# Out:
#                1992           1993           1994           1995
# 0      -8941.531897  -51896.094813  152336.932066  -69708.439062
# 1     127788.667612  198350.518755  192947.128056  -13289.977022
# 2     -71887.743011 -123518.252821  389950.263156  -30178.390991
# 3     -79146.060869 -129916.759685  -93006.152024   55052.181256
# 4     425156.114501  216119.147314  100818.575896  152883.621657
# 5     310681.166595   49845.883728    5529.230706   12930.835194
# 6      50581.575349  149135.648505  -32989.370488   63700.461932
# 7      88349.230566   62807.672113  223942.967178   64148.489835
# 8     185804.513522   23365.577348  -66721.580898  -29316.268556
# 9     281286.947277 -109686.264981   47826.269111   59645.677367
# 10    233437.871517  143973.220873 -192967.663433  -52635.307654
# 11   -227244.221822  149211.328778  204584.561046   34336.438541
# 12     86998.326686   97627.497748   38869.703622   35651.001159
# 13     77782.575787  -47123.013558   32040.564523    5400.939983
# 14    302583.367033  189071.044852 -147185.190711  100867.454146
# 15    209285.868118  116617.008245    4025.232730   54343.043728
# 16   -368327.461932   19673.406721   79921.616963   -3899.503204
# 17    -42368.507428   99051.501841  328776.090270   48050.133302
# 18    365805.061905   28371.886237 -182624.859166   19412.920262
# 19    -55713.947167   31873.611779  -36343.057416  120522.850238
# 20    -75948.289104  -41129.903198  -79062.500439   78198.485628
# 21    127397.002082  148282.489943  251626.386131  112562.785435
# 22    681788.783886  -75385.183578  -78444.334782   27994.669028
# 23   -172245.504871  -17940.948483  203774.943031  -16385.665394
# 24    -83417.460608    5989.008121   15047.966705   58009.028372
# 25     56824.255135   12514.078074  320531.493015  -15362.310545
# 26     92522.712383   51109.775598  304706.467877  -22595.655584
# 27    136754.413630   50881.532197  224425.509343  -30970.881018
# 28     32188.055555  149406.296856 -123087.581536   26265.814182
# 29    300761.958723   31162.466177   94658.527746  209825.692882
# ...             ...            ...            ...            ...
# 3620  166069.066752  118097.037989   91705.488445   48454.275483
# 3621  -94092.979208  -86959.395276  251117.848685   82772.802742
# 3622   -8053.847696  -17977.451815  167640.502317  120654.352024
# 3623  -76933.464704 -196871.770735 -237201.424606   59175.304535
# 3624   14538.069320  -78628.715111 -251474.769728  -36588.103215
# 3625  251103.033929  113147.009583  233536.303598   -5132.851011
# 3626  -22733.673307  -89183.720598   75467.603022   71414.268888
# 3627  267716.743708  -50979.449596  -38136.030588  109932.771259
# 3628 -395209.384721  -65535.636196   48491.810886    8593.070715
# 3629  271852.854117  -59353.767451  -49579.178708   62084.814481
# 3630  120715.697368   72899.992967 -169640.335102  -22679.095577
# 3631 -355947.615528   23871.029181  135703.619226  138630.899719
# 3632   -5307.186400 -171961.653041  106938.598353   22824.410979
# 3633 -473897.771965  198285.454409  139392.240143   25104.161170
# 3634  404229.924267   83507.420667  -64356.362713  -41473.830457
# 3635  376944.510876  133038.005845   48815.619937  -68846.073869
# 3636  122125.022554   85680.351811 -146941.987837  104480.885199
# 3637 -226859.186251   49043.404885  147184.086629  -18906.197730
# 3638   35573.176407 -153490.820097   81242.824039  -16535.685094
# 3639 -342424.249551  200030.512819  -65784.913980   99557.678348
# 3640  171938.760289  -44566.520071  165085.806360  -13901.388118
# 3641  150650.759924  101032.122475   74735.174090   50173.686673
# 3642  203663.976475  117648.199945  107329.726875   53965.990717
# 3643 -377877.158072  160475.622607  199250.734156    4128.990173
# 3644 -197214.093861  -13759.888342  -36792.202754   72202.595138
# 3645   24185.008589  -37333.493572  -71861.846997   39937.199964
# 3646  -56826.729535  103019.841174   26375.113219  139472.114293
# 3647  -67319.766489  179746.127403  -29328.078384   59386.186379
# 3648  113377.299342   13455.493990   65858.761714   73362.229590
# 3649   -4494.878538   34442.898855  -91542.001049   28705.082908
#
# [3650 rows x 4 columns]

# %%
import math

mean = list(df.mean())

std = list(df.std())

confidence = []

for i in range (4) :
    confidence.append(1.96*(std[i]/math.sqrt(len(df))))
    
confidence
# Out:
# [6508.897969970325, 3192.2543136890313, 4553.9022870882427, 2263.8517443103765]

# %%
Y = 39500

def compute_prob(Y):
    nearest = 150
    df_p = pd.DataFrame()
    df_p['diff'] = nearest*((Y - df.mean())//nearest)
    df_p['sign'] = df_p['diff'].abs()/df_p['diff']
    old_range = abs(df_p['diff']).min(), df_p['diff'].abs().max()
    new_range = .5,1
    df_p['shade'] = df_p['sign']*np.interp(df_p['diff'].abs(), old_range, new_range)
    return df_p['shade']

# %%
from matplotlib import cm

shade = list(compute_prob(Y))
colors = ['White' if  x == 0 else cm.Reds(abs(x))
         if x<0 else cm.Blues(abs(x)) for x in shade]

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

plt.figure(figsize=(8, 8))

title = plt.title('Easy Option - Bar Coloring')
plt.xticks(range(len(df.columns)), df.columns)
plt.bar(range(len(df.columns)), 
        height = df.values.mean(axis = 0), 
        yerr=confidence, 
        error_kw={'capsize': 10, 'elinewidth': 2, 'alpha':0.7}, 
        color = colors)
h_line = plt.axhline(y=Y, color = 'black', label = 'Y')
h_text = plt.text(3.5, 40000, Y)
for spine in plt.gca().spines.values():
    spine.set_visible(False)

plt.show()
